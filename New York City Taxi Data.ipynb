# %%
# Import pandas
import pandas as pd

# %%
# Explanation of the columns: https://www.nyc.gov/assets/tlc/downloads/pdf/data_dictionary_trip_records_yellow.pdf
dataset = "https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-01.parquet"

# %%
# Read the dataset and save the DataFrame in a variable
df = pd.read_parquet(dataset)

# %%
# Get the shape of the dataframe
df.shape
# Out:
# (3475226, 19)

# %%
# Get information about the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3475226 entries, 0 to 3475225
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   tpep_pickup_datetime   datetime64[us]
#  2   tpep_dropoff_datetime  datetime64[us]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int32
#  8   DOLocationID           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  Airport_fee            float64
# dtypes: datetime64[us](2), float64(12), int32(3), int64(1), object(1)
# ...

# %%
# Describe the data (find count, mean, min, max, etc)
df.describe()
# Out:
#            VendorID        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count  3.475226e+06                     3475226                     3475226
# mean   1.785428e+00  2025-01-17 11:02:55.910964  2025-01-17 11:17:56.997901
# min    1.000000e+00         2024-12-31 20:47:55         2024-12-18 07:52:40
# 25%    2.000000e+00         2025-01-10 07:59:01  2025-01-10 08:15:29.500000
# 50%    2.000000e+00         2025-01-17 15:41:33         2025-01-17 15:59:34
# 75%    2.000000e+00         2025-01-24 19:34:06         2025-01-24 19:48:31
# max    7.000000e+00         2025-02-01 00:00:44         2025-02-01 23:44:11
# std    4.263282e-01                         NaN                         NaN
#
#        passenger_count  trip_distance    RatecodeID  PULocationID  \
# count     2.935077e+06   3.475226e+06  2.935077e+06  3.475226e+06
# mean      1.297859e+00   5.855126e+00  2.482535e+00  1.651916e+02
# min       0.000000e+00   0.000000e+00  1.000000e+00  1.000000e+00
# ...

# %%
# View the dataframe
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2025-01-01 00:18:38   2025-01-01 00:26:59              1.0
# 1               1  2025-01-01 00:32:40   2025-01-01 00:35:13              1.0
# 2               1  2025-01-01 00:44:04   2025-01-01 00:46:01              1.0
# 3               2  2025-01-01 00:14:27   2025-01-01 00:20:01              3.0
# 4               2  2025-01-01 00:21:34   2025-01-01 00:25:06              3.0
# ...           ...                  ...                   ...              ...
# 3475221         2  2025-01-31 23:01:48   2025-01-31 23:16:29              NaN
# 3475222         2  2025-01-31 23:50:29   2025-02-01 00:17:27              NaN
# 3475223         2  2025-01-31 23:26:59   2025-01-31 23:43:01              NaN
# 3475224         2  2025-01-31 23:14:34   2025-01-31 23:34:52              NaN
# 3475225         2  2025-01-31 23:56:42   2025-02-01 00:07:27              NaN
#
# ...

# %%
# Get a sample of the dataframe
df.sample(15)
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 1910466         2  2025-01-21 20:09:17   2025-01-21 20:22:07              2.0
# 3351550         2  2025-01-25 20:50:59   2025-01-25 20:58:01              NaN
# 320697          1  2025-01-04 20:46:30   2025-01-04 20:49:42              1.0
# 2444915         2  2025-01-27 08:43:56   2025-01-27 08:54:27              1.0
# 2244263         2  2025-01-24 23:29:19   2025-01-24 23:29:26              1.0
# 3437841         2  2025-01-30 19:06:49   2025-01-30 19:26:18              NaN
# 1623186         2  2025-01-18 14:02:38   2025-01-18 14:05:46              1.0
# 2500374         2  2025-01-27 18:23:38   2025-01-27 19:12:24              1.0
# 3000040         2  2025-01-09 17:25:44   2025-01-09 17:35:27              NaN
# 2776980         2  2025-01-30 16:02:50   2025-01-30 16:24:06              1.0
# 2446209         1  2025-01-27 08:31:02   2025-01-27 08:47:42              1.0
# ...

# %%
# Find the missing values of each column
df.isna().sum()
# Out:
# VendorID                      0
# tpep_pickup_datetime          0
# tpep_dropoff_datetime         0
# passenger_count          540149
# trip_distance                 0
# RatecodeID               540149
# store_and_fwd_flag       540149
# PULocationID                  0
# DOLocationID                  0
# payment_type                  0
# fare_amount                   0
# extra                         0
# mta_tax                       0
# tip_amount                    0
# tolls_amount                  0
# improvement_surcharge         0
# total_amount                  0
# congestion_surcharge     540149
# Airport_fee              540149
# dtype: int64

# %%
df = df.drop('store_and_fwd_flag', axis=1)

# %%
# Drop all nan values
df.dropna(inplace=True);

# %%
# Find the missing values of each column
df.isna().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# congestion_surcharge     0
# Airport_fee              0
# dtype: int64

# %%
# View the dataframe
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2025-01-01 00:18:38   2025-01-01 00:26:59              1.0
# 1               1  2025-01-01 00:32:40   2025-01-01 00:35:13              1.0
# 2               1  2025-01-01 00:44:04   2025-01-01 00:46:01              1.0
# 3               2  2025-01-01 00:14:27   2025-01-01 00:20:01              3.0
# 4               2  2025-01-01 00:21:34   2025-01-01 00:25:06              3.0
# ...           ...                  ...                   ...              ...
# 2935072         1  2025-01-31 23:01:14   2025-01-31 23:08:49              1.0
# 2935073         1  2025-01-31 23:11:28   2025-01-31 23:14:45              1.0
# 2935074         2  2025-01-31 23:14:32   2025-01-31 23:28:02              1.0
# 2935075         2  2025-01-31 23:15:51   2025-01-31 23:21:22              2.0
# 2935076         2  2025-01-31 23:34:39   2025-01-31 23:46:00              2.0
#
# ...
